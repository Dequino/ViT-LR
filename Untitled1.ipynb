# %%
# %matplotlib inline
import cv2
from matplotlib import pyplot as plt

# %%
im = cv2.imread("/home/adequino/work/ar1-pytorch/core50/s1/o1/C_01_01_000.png")

# %%
plt.imshow(im)
plt.show()

# %%
imS = cv2.resize(im, (224, 224))

# %%
plt.imshow(imS)
plt.show()
